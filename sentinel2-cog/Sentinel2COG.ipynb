# %% [markdown]
# # Cloudbutton Geospatial Use Case: Sentinel2 Satellital Image Processing

# %%
import sys
sys.path.append('../')
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %%
import sentinelsat
import ipywidgets as widgets
import numpy as np
import os
import time
import lithops
import random
import shutil
import rasterio
import re
import tempfile
import zipfile
import subprocess
import glob
import multiprocessing as mp
import json
from rio_cogeo import cogeo

from collections import defaultdict
from datetime import date

from matplotlib import pyplot as plt
from rasterio.io import MemoryFile
from zipfile import ZipFile
from ipyleaflet import Map, basemaps, basemap_to_tiles
from lithops import Storage

from cloudbutton_geospatial.utils import notebook as notebook_utils
from cloudbutton_geospatial.io_utils.ndvi import get_ndvi_params, ndvi_calculation, ndvi_tile_sentinel, get_subset_raster, lonlat_to_utm, get_poly_within
from cloudbutton_geospatial.io_utils.plot import tiff_overview, plot_map

os.environ['CURL_CA_BUNDLE'] = '/etc/ssl/certs/ca-certificates.crt'
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %% [markdown]
# Set the environmental variables *SENTINEL_USERNAME* and *SENTINEL_PASSWORD* to match your Sentinel-2 credentials. You can register and access data for free at https://sentinel.esa.int/web/sentinel/sentinel-data-access/registration:

# %%
SENTINEL_USERNAME = 'zhudayong'
SENTINEL_PASSWORD = 'Zhuyong_870613'
STORAGE_BACKEND = 'aws_s3'
BATCH_BACKEND = 'aws_batch'
BATCH_RUNTIME = 'cloudbutton-geospatial-sentinel:01'
FAAS_BACKEND = 'aws_lambda'
FAAS_RUNTIME = ''
STORAGE_BUCKET = 'cloudbutton-geospatial-sentinel'
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %%
# %matplotlib inline
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %%
cloud_storage = Storage(backend=STORAGE_BACKEND)
# Out:
# 2023-10-08 02:20:53,716 [INFO] aws_s3.py:68 -- S3 client created - Region: us-west-2
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %% [markdown]
# ## Input parameters

# %% [markdown]
# Select the date interval in which tiles will be processed:

# %%
from_day, to_day = notebook_utils.pick_date_range()
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JavascriptFormatter object at 0x7f15d6366a60>, DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1))
# DatePicker(value=datetime.date(2019, 5, 1), description='From day', step=1)
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JavascriptFormatter object at 0x7f15d6366a60>, DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1))
# DatePicker(value=datetime.date(2019, 5, 15), description='To day', step=1)

# %% [markdown]
# Select the tile's cloud percentage threshold:1

# %%
percentage = notebook_utils.pick_percentage_slider()
from_day.value
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JavascriptFormatter object at 0x7f15d6366a60>, IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness'))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
# IntSlider(value=15, continuous_update=False, description='Percentage of cloudiness')
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PlainTextFormatter object at 0x7f15d6366910>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, datetime.date(2019, 5, 1))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JavascriptFormatter object at 0x7f15d6366a60>, datetime.date(2019, 5, 1))
# datetime.date(2019, 5, 1)

# %% [markdown]
# Select the area which delimites the tiles you want to process (left click to mark a point in the map, right click to erase current selection):

# %%
map_region = notebook_utils.MapRegion(zoom=8)
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JavascriptFormatter object at 0x7f15d6366a60>, Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text', 'zoom_out_title']), AttributionControl(options=['position', 'prefix'], position='bottomright')), crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapStyle(cursor='move'), layers=(TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, Tiles style by <a href="https://www.hotosm.org/" target="_blank">Humanitarian OpenStreetMap Team</a> hosted by <a href="https://openstreetmap.fr/" target="_blank">OpenStreetMap France</a>', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.HOT', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://a.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png'), Polygon(color='green', fill_color='green', locations=[[]], options=['color', 'dash_array', 'draggable', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'transform', 'weight'])), options=['bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'fullscreen', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'interpolation', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'prefer_canvas', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_delta', 'zoom_snap'], style=MapStyle(), zoom=8.0))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
# Map(center=[41.82046, 1.86768], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Get Sentinel-2 metadata

# %%
# locations = map_region.get_region()

# Tarragona data
locations = [[1.5481363013595886, 41.16508628430497],
 [0.8177319989996914, 40.62111912603713],
 [0.6008074129604647, 40.60652433834119],
 [0.4552757286556909, 40.868742532626996],
 [0.3811369460853299, 41.03883697553436],
 [0.427816920296289, 41.247740935856484],
 [0.694167361382423, 41.33441592882952],
 [1.097811844265526, 41.39831645175795],
 [1.452030472101722, 41.365343372983396],
 [1.5481363013595886, 41.16508628430497]]


# debug
#locations = [[-1.32110595703125, 37.57329031970199],
#   [-2.0681762695312504, 37.684227882053044],
#   [-1.636962890625, 38.24289903439589],
#   [-0.7745361328125, 38.12199840979802],
#   [-1.32110595703125, 37.57329031970199]]

print(locations)
# Out:
# [[1.5481363013595886, 41.16508628430497], [0.8177319989996914, 40.62111912603713], [0.6008074129604647, 40.60652433834119], [0.4552757286556909, 40.868742532626996], [0.3811369460853299, 41.03883697553436], [0.427816920296289, 41.247740935856484], [0.694167361382423, 41.33441592882952], [1.097811844265526, 41.39831645175795], [1.452030472101722, 41.365343372983396], [1.5481363013595886, 41.16508628430497]]
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %%
geo_json_area = {
    "features": [
        {
            "geometry": {
                "coordinates":[locations],
                "type": "Polygon"
            },
            "properties": {},
            "type": "Feature"
        }
    ],
    "type": "FeatureCollection"
}
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %% [markdown]
# Using the selected parameters, get the identifiers of the selected tiles from Sentinel-2:

# %%
sentinel_api = sentinelsat.SentinelAPI(SENTINEL_USERNAME,
                                       SENTINEL_PASSWORD,
                                       'https://apihub.copernicus.eu/apihub')
footprint = sentinelsat.geojson_to_wkt(geo_json_area)
products = sentinel_api.query(footprint,
                              date=(from_day.value, to_day.value),
                              platformname='Sentinel-2',
                              producttype=('S2MS2Ap', 'S2MSI1C'),
                              cloudcoverpercentage=(0, percentage.value))
tiles_ids = []
products_ids = []

for product in list(products.keys()):
    product_id = products[product]['identifier']
    tile_id = products[product]['level1cpdiidentifier']
    tiles_ids.append(tile_id)
    products_ids.append(product_id)

geojson_products = sentinel_api.to_geojson(products)
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %%
print('Number of tiles: {}'.format(len(geojson_products['features'])))
# Out:
# Number of tiles: 15
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %%
#from sentinelhub import AwsProductRequest
#from sentinelhub import AwsTile

#product_id = 'S2A_MSIL1C_20210902T105031_N0301_R051_T31TBE_20210902T130744'
#data_folder = './AwsData'
#request = AwsProductRequest(product_id=product_id, data_folder=data_folder, safe_format=True)

# Uncomment the the following line to download the data:
#data_list = request.get_data(save_data=True)
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f4d19857ac0>, <sqlite3.Connection object at 0x7f4d19a417b0>)

# %% [markdown]
# ## Prepare dataset

# %%
products.keys()
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PlainTextFormatter object at 0x7f15d6366910>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JavascriptFormatter object at 0x7f15d6366a60>, odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9']))
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
# odict_keys(['2eb1466e-e92d-46c6-9b3c-2124f6736655', '951d8643-c6d5-4b59-9809-af46c83ebb57', 'c02d1f5f-7f41-426a-9ef7-d4ffaeb4e0df', '91f70604-8906-4b41-a32a-b956a3228cf0', 'c0a6a5d6-d0c2-4e42-8554-0afca0d14686', '3a4fe125-6b52-4f95-91a7-4ae1ce13a4f7', 'f482791f-3c09-488a-8e3b-8d163079c0c9', '5f85cdea-05de-4349-ba4e-aff574adc284', '22f494b4-d6b2-4085-a497-3505c3b5d9c2', '9ff9331a-ceaa-40ff-a4eb-f46969433ea5', '5fc95620-8ee3-4728-9a82-4d52077c5e33', '7716ec35-1644-4228-9c53-5dd9769ca7e1', '47fc1c3b-5d33-4c93-9b85-5cb85048a225', '62952613-1ac4-4ade-93a3-8657fb3b84b5', 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9'])

# %%
products['2eb1466e-e92d-46c6-9b3c-2124f6736655']
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PlainTextFormatter object at 0x7f15d6366910>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JavascriptFormatter object at 0x7f15d6366a60>, {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'})
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
# {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200',
#  'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value",
#  'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/",
#  'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value",
#  'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB',
#  'ondemand': 'false',
#  'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000),
#  'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000),
#  'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000),
#  'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000),
#  'orbitnumber': 20311,
#  'relativeorbitnumber': 8,
#  'cloudcoverpercentage': 3.3156,
#  'sensoroperationalmode': 'INS-NOBS',
#  'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#  'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))',
#  'tileid': '31TCF',
#  'hv_order_tileid': 'TF31C',
#  'format': 'SAFE',
#  'processingbaseline': '02.07',
#  'platformname': 'Sentinel-2',
#  'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE',
#  'instrumentname': 'Multi-Spectral Instrument',
#  'instrumentshortname': 'MSI',
#  'size': '625.94 MB',
#  's2datatakeid': 'GS2A_20190513T104031_020311_N02.07',
#  'producttype': 'S2MSI1C',
#  'platformidentifier': '2015-028A',
#  'orbitdirection': 'DESCENDING',
#  'platformserialidentifier': 'Sentinel-2A',
#  'processinglevel': 'Level-1C',
#  'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200',
#  'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07',
#  'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655',
#  'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07',
#  'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}

# %%
products
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values()&&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
#  odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition':  ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': date ...
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PlainTextFormatter object at 0x7f15d6366910>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datet ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.d ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': dateti ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.da ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.da ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.da ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.d ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime. ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, OrderedDict([('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.d ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# ...
#                'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'ingestiondate': datetime.datetime(2019, 5, 1, 18, 32, 2, 392000),
#                'orbitnumber': 11231,
#                'relativeorbitnumber': 51,
#                'cloudcoverpercentage': 1.0518,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.59640146890937,-0.5454712 40.62894899386581,0.750865220008873 39.64044856303257,0.783235343452924 39.609013147606916,-0.49450684 40.59640146890937,-0.5454712</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.49450684 39.609013147606916, 1.4894561334971356e-17 39.62117916055345, 0.783235343452924 39.64044856303257, 0.750865220008873 40.62894899386581, -1.1905948046165649e-17 40.610096785357314, -0.5454712 40.59640146890937, -0.49450684 39.609013147606916)))',
#                'tileid': '31TBE',
#                'hv_order_tileid': 'TE31B',
#                'format': 'SAFE',
#                'processingbaseline': '02.07',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBE_20190501T130728.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '797.30 MB',
#                's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBE_20190501T130728',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TBE_N02.07',
#                'uuid': '5fc95620-8ee3-4728-9a82-4d52077c5e33',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TBE_N02.07',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'}),
#              ('7716ec35-1644-4228-9c53-5dd9769ca7e1',
#               {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T30TYL_20190501T130728',
#                'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('7716ec35-1644-4228-9c53-5dd9769ca7e1')/$value",
#                'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('7716ec35-1644-4228-9c53-5dd9769ca7e1')/",
#                'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('7716ec35-1644-4228-9c53-5dd9769ca7e1')/Products('Quicklook')/$value",
#                'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 852.67 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'ingestiondate': datetime.datetime(2019, 5, 1, 18, 27, 31, 411000),
#                'orbitnumber': 11231,
#                'relativeorbitnumber': 51,
#                'cloudcoverpercentage': 0.2425,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>41.5268622914542,-0.603302 41.49194363396281,0.710574648674325 40.50488583658978,0.65555501440102 40.53861750192735,-0.6388855 41.5268622914542,-0.603302</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((0.65555501440102 40.50488583658978, 0.710574648674325 41.49194363396281, -1.2757692614189051e-17 41.51082844541308, -0.603302 41.5268622914542, -0.6388855 40.53861750192735, 1.9339596288131015e-17 40.52196886366605, 0.65555501440102 40.50488583658978)))',
#                'tileid': '30TYL',
#                'hv_order_tileid': 'TL30Y',
#                'format': 'SAFE',
#                'processingbaseline': '02.07',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T30TYL_20190501T130728.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '852.67 MB',
#                's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T30TYL_20190501T130728',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T30TYL_N02.07',
#                'uuid': '7716ec35-1644-4228-9c53-5dd9769ca7e1',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T30TYL_N02.07',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'}),
#              ('47fc1c3b-5d33-4c93-9b85-5cb85048a225',
#               {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCE_20190501T130728',
#                'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('47fc1c3b-5d33-4c93-9b85-5cb85048a225')/$value",
#                'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('47fc1c3b-5d33-4c93-9b85-5cb85048a225')/",
#                'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('47fc1c3b-5d33-4c93-9b85-5cb85048a225')/Products('Quicklook')/$value",
#                'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 529.59 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'ingestiondate': datetime.datetime(2019, 5, 1, 18, 25, 38, 108000),
#                'orbitnumber': 11231,
#                'relativeorbitnumber': 51,
#                'cloudcoverpercentage': 0.9141,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.643047737221266,1.73935014766585 40.617025151275946,1.729937943974527 40.47079155758107,1.67721340422739 40.32446770303216,1.624540912067755 40.178082437376425,1.571999987811006 40.031631736700575,1.519690524897823 39.885181580616525,1.467620933702627 39.7387242344685,1.415691129887569 39.64862346318864,1.383837310903674 39.638218234831534,0.669348697399363 40.62663972727231,0.635319212972606 40.643047737221266,1.73935014766585</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((0.669348697399363 39.638218234831534, 1.383837310903674 39.64862346318864, 1.415691129887569 39.7387242344685, 1.467620933702627 39.885181580616525, 1.519690524897823 40.031631736700575, 1.571999987811006 40.178082437376425, 1.624540912067755 40.32446770303216, 1.67721340422739 40.47079155758107, 1.729937943974527 40.617025151275946, 1.73935014766585 40.643047737221266, 0.635319212972606 40.62663972727231, 0.669348697399363 39.638218234831534)))',
#                'tileid': '31TCE',
#                'hv_order_tileid': 'TE31C',
#                'format': 'SAFE',
#                'processingbaseline': '02.07',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCE_20190501T130728.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '529.59 MB',
#                's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCE_20190501T130728',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TCE_N02.07',
#                'uuid': '47fc1c3b-5d33-4c93-9b85-5cb85048a225',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TCE_N02.07',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'}),
#              ('62952613-1ac4-4ade-93a3-8657fb3b84b5',
#               {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBF_20190501T130728',
#                'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('62952613-1ac4-4ade-93a3-8657fb3b84b5')/$value",
#                'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('62952613-1ac4-4ade-93a3-8657fb3b84b5')/",
#                'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('62952613-1ac4-4ade-93a3-8657fb3b84b5')/Products('Quicklook')/$value",
#                'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 853.27 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'ingestiondate': datetime.datetime(2019, 5, 1, 18, 24, 49, 775000),
#                'orbitnumber': 11231,
#                'relativeorbitnumber': 51,
#                'cloudcoverpercentage': 0.2712,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>41.49564643575739,-0.5941162 41.52923550071836,0.719948115495856 40.54090999482793,0.753813881598681 40.50846282585221,-0.5408325 41.49564643575739,-0.5941162</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.5408325 40.50846282585221, 1.3101912763842559e-17 40.52201747966694, 0.753813881598681 40.54090999482793, 0.719948115495856 41.52923550071836, -5.6985729713309160e-18 41.51083276065857, -0.5941162 41.49564643575739, -0.5408325 40.50846282585221)))',
#                'tileid': '31TBF',
#                'hv_order_tileid': 'TF31B',
#                'format': 'SAFE',
#                'processingbaseline': '02.07',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBF_20190501T130728.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '853.27 MB',
#                's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBF_20190501T130728',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TBF_N02.07',
#                'uuid': '62952613-1ac4-4ade-93a3-8657fb3b84b5',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TBF_N02.07',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'}),
#              ('bb9027de-6f91-43e4-8cd9-bf35cfc448a9',
#               {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCF_20190501T130728',
#                'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('bb9027de-6f91-43e4-8cd9-bf35cfc448a9')/$value",
#                'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('bb9027de-6f91-43e4-8cd9-bf35cfc448a9')/",
#                'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('bb9027de-6f91-43e4-8cd9-bf35cfc448a9')/Products('Quicklook')/$value",
#                'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 760.49 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#                'ingestiondate': datetime.datetime(2019, 5, 1, 18, 21, 9, 81000),
#                'orbitnumber': 11231,
#                'relativeorbitnumber': 51,
#                'cloudcoverpercentage': 2.3334,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>41.15311144037381,1.924907491200061 41.05550012725967,1.889168309245836 40.90937535066946,1.835866226759284 40.76322949618436,1.782819124873532 40.617025151275946,1.729937943974527 40.5544664448336,1.707382394862937 40.538607851727775,0.638419022640916 41.52685230149302,0.6028173807795 41.546758769895376,1.918508192616414 41.15311144037381,1.924907491200061</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((0.638419022640916 40.538607851727775, 1.707382394862937 40.5544664448336, 1.729937943974527 40.617025151275946, 1.782819124873532 40.76322949618436, 1.835866226759284 40.90937535066946, 1.889168309245836 41.05550012725967, 1.924907491200061 41.15311144037381, 1.918508192616414 41.546758769895376, 0.6028173807795 41.52685230149302, 0.638419022640916 40.538607851727775)))',
#                'tileid': '31TCF',
#                'hv_order_tileid': 'TF31C',
#                'format': 'SAFE',
#                'processingbaseline': '02.07',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCF_20190501T130728.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '760.49 MB',
#                's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCF_20190501T130728',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TCF_N02.07',
#                'uuid': 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TCF_N02.07',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'})])

# %%
def download_dataset(product_id, product_meta, storage):
    
    product = {product_id: product_meta}
    storage_prefix = 'sentinel'
    tiles_in_storage = storage.list_keys(bucket=STORAGE_BUCKET, prefix=storage_prefix)
    
    tile_id = products[product_id]['identifier']
    product_storage_key = os.path.join(storage_prefix, tile_id+'.zip')
    if product_storage_key in tiles_in_storage:
        return tile_id

    sentinel_api = sentinelsat.SentinelAPI(user=os.environ["SENTINEL_USERNAME"],
                                           password=os.environ["SENTINEL_PASSWORD"],
                                           show_progressbars=False)
    
    tmpdir = tempfile.gettempdir()
    sentinel_api.download_all(product, directory_path=tmpdir)

    tile_id = products[product_id]['identifier']
    print(f"Tile name: {tile_id}")
    product_local_file = os.path.join(tmpdir, tile_id+'.zip')
    product_storage_key = os.path.join(storage_prefix, tile_id+'.zip')
    print(f"Uploading tile {tile_id} to Storage")
    with open(product_local_file, 'rb') as tiffile:
        storage.put_object(bucket=STORAGE_BUCKET, key=product_storage_key, body=tiffile)
    
    return tile_id
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %%
iterdata = []

for product_id, product_meta in products.items():
    iterdata.append((product_id, product_meta))
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)

# %%
iterdata
# Out:
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.IPythonDisplayFormatter object at 0x7f15d63c5dc0>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.dat ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">, <Parameter "include=None">, <Parameter "exclude=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MimeBundleFormatter object at 0x7f15d63c5fd0>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetim ...
# &&&&&&&&&&&&&&&&&&&&&& param include=None
# &&&&&&&&&&&&&&&&&&&&&& param.kind POSITIONAL_OR_KEYWORD
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PlainTextFormatter object at 0x7f15d6366910>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.HTMLFormatter object at 0x7f15d6366970>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019 ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.MarkdownFormatter object at 0x7f15d63669d0>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime( ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.SVGFormatter object at 0x7f15d6366580>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PNGFormatter object at 0x7f15d6366940>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.PDFFormatter object at 0x7f15d63667c0>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JPEGFormatter object at 0x7f15d63669a0>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019 ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.LatexFormatter object at 0x7f15d6366a30>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(201 ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.formatters.JSONFormatter object at 0x7f15d6366a00>, [('2eb1466e-e92d-46c6-9b3c-2124f6736655', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('2eb1466e-e92d-46c6-9b3c-2124f6736655')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 625.94 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'ingestiondate': datetime.datetime(2019, 5, 14, 0, 14, 35, 33000), 'orbitnumber': 20311, 'relativeorbitnumber': 8, 'cloudcoverpercentage': 3.3156, 'sensoroperationalmode': 'INS-NOBS', 'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.538621967697445,0.639370522842896 40.60988705401636,0.66102538148975 40.75693935066691,0.705878332916836 40.90396232861502,0.751122361141877 41.05077095245479,0.797571657396485 41.19813933963176,0.84244106987459 41.34499811266775,0.889329041265406 41.49247146867887,0.93413063818571 41.53205132824133,0.94643994531388 41.546758769895376,1.918508192616414 40.55783709926159,1.934584524326618 40.538621967697445,0.639370522842896</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>', 'footprint': 'MULTIPOLYGON (((0.639370522842896 40.538621967697445, 1.934584524326618 40.55783709926159, 1.918508192616414 41.546758769895376, 0.94643994531388 41.53205132824133, 0.93413063818571 41.49247146867887, 0.889329041265406 41.34499811266775, 0.84244106987459 41.19813933963176, 0.797571657396485 41.05077095245479, 0.751122361141877 40.90396232861502, 0.705878332916836 40.75693935066691, 0.66102538148975 40.60988705401636, 0.639370522842896 40.538621967697445)))', 'tileid': '31TCF', 'hv_order_tileid': 'TF31C', 'format': 'SAFE', 'processingbaseline': '02.07', 'platformname': 'Sentinel-2', 'filename': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200.SAFE', 'instrumentname': 'Multi-Spectral Instrument', 'instrumentshortname': 'MSI', 'size': '625.94 MB', 's2datatakeid': 'GS2A_20190513T104031_020311_N02.07', 'producttype': 'S2MSI1C', 'platformidentifier': '2015-028A', 'orbitdirection': 'DESCENDING', 'platformserialidentifier': 'Sentinel-2A', 'processinglevel': 'Level-1C', 'identifier': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCF_20190513T141200', 'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'uuid': '2eb1466e-e92d-46c6-9b3c-2124f6736655', 'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190513T141200_A020311_T31TCF_N02.07', 'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190513T141200_S20190513T104742_N02.07'}), ('951d8643-c6d5-4b59-9809-af46c83ebb57', {'title': 'S2A_MSIL1C_20190513T104031_N0207_R008_T31TCE_20190513T141200', 'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/$value", 'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/", 'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('951d8643-c6d5-4b59-9809-af46c83ebb57')/Products('Quicklook')/$value", 'summary': 'Date: 2019-05-13T10:40:31.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 574.06 MB', 'ondemand': 'false', 'datatakesensingstart': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'beginposition': datetime.datetime(2019, 5, 13, 10, 40, 31, 24000), 'endposition': datetime.datetime(2019 ...
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "obj">])
# ...
#    'footprint': 'MULTIPOLYGON (((0.638419022640916 40.538607851727775, 1.713180421110215 40.55455246138146, 1.746046274772569 40.64532490816595, 1.799116757225211 40.79159143180375, 1.852337064048339 40.93782362913416, 1.905683776746883 41.08392664949911, 1.925168225955281 41.13707256693102, 1.918508192616414 41.546758769895376, 0.6028173807795 41.52685230149302, 0.638419022640916 40.538607851727775)))',
#    'tileid': '31TCF',
#    'hv_order_tileid': 'TF31C',
#    'format': 'SAFE',
#    'processingbaseline': '02.07',
#    'platformname': 'Sentinel-2',
#    'filename': 'S2A_MSIL1C_20190506T105031_N0207_R051_T31TCF_20190506T143619.SAFE',
#    'instrumentname': 'Multi-Spectral Instrument',
#    'instrumentshortname': 'MSI',
#    'size': '781.31 MB',
#    's2datatakeid': 'GS2A_20190506T105031_020211_N02.07',
#    'producttype': 'S2MSI1C',
#    'platformidentifier': '2015-028A',
#    'orbitdirection': 'DESCENDING',
#    'platformserialidentifier': 'Sentinel-2A',
#    'processinglevel': 'Level-1C',
#    'identifier': 'S2A_MSIL1C_20190506T105031_N0207_R051_T31TCF_20190506T143619',
#    'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190506T143619_A020211_T31TCF_N02.07',
#    'uuid': '9ff9331a-ceaa-40ff-a4eb-f46969433ea5',
#    'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_SGS__20190506T143619_A020211_T31TCF_N02.07',
#    'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_SGS__20190506T143619_S20190506T105918_N02.07'}),
#  ('5fc95620-8ee3-4728-9a82-4d52077c5e33',
#   {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBE_20190501T130728',
#    'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('5fc95620-8ee3-4728-9a82-4d52077c5e33')/$value",
#    'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('5fc95620-8ee3-4728-9a82-4d52077c5e33')/",
#    'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('5fc95620-8ee3-4728-9a82-4d52077c5e33')/Products('Quicklook')/$value",
#    'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 797.30 MB',
#    'ondemand': 'false',
#    'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'ingestiondate': datetime.datetime(2019, 5, 1, 18, 32, 2, 392000),
#    'orbitnumber': 11231,
#    'relativeorbitnumber': 51,
#    'cloudcoverpercentage': 1.0518,
#    'sensoroperationalmode': 'INS-NOBS',
#    'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.59640146890937,-0.5454712 40.62894899386581,0.750865220008873 39.64044856303257,0.783235343452924 39.609013147606916,-0.49450684 40.59640146890937,-0.5454712</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#    'footprint': 'MULTIPOLYGON (((-0.49450684 39.609013147606916, 1.4894561334971356e-17 39.62117916055345, 0.783235343452924 39.64044856303257, 0.750865220008873 40.62894899386581, -1.1905948046165649e-17 40.610096785357314, -0.5454712 40.59640146890937, -0.49450684 39.609013147606916)))',
#    'tileid': '31TBE',
#    'hv_order_tileid': 'TE31B',
#    'format': 'SAFE',
#    'processingbaseline': '02.07',
#    'platformname': 'Sentinel-2',
#    'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBE_20190501T130728.SAFE',
#    'instrumentname': 'Multi-Spectral Instrument',
#    'instrumentshortname': 'MSI',
#    'size': '797.30 MB',
#    's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#    'producttype': 'S2MSI1C',
#    'platformidentifier': '2017-013A',
#    'orbitdirection': 'DESCENDING',
#    'platformserialidentifier': 'Sentinel-2B',
#    'processinglevel': 'Level-1C',
#    'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBE_20190501T130728',
#    'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TBE_N02.07',
#    'uuid': '5fc95620-8ee3-4728-9a82-4d52077c5e33',
#    'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TBE_N02.07',
#    'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'}),
#  ('7716ec35-1644-4228-9c53-5dd9769ca7e1',
#   {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T30TYL_20190501T130728',
#    'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('7716ec35-1644-4228-9c53-5dd9769ca7e1')/$value",
#    'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('7716ec35-1644-4228-9c53-5dd9769ca7e1')/",
#    'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('7716ec35-1644-4228-9c53-5dd9769ca7e1')/Products('Quicklook')/$value",
#    'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 852.67 MB',
#    'ondemand': 'false',
#    'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'ingestiondate': datetime.datetime(2019, 5, 1, 18, 27, 31, 411000),
#    'orbitnumber': 11231,
#    'relativeorbitnumber': 51,
#    'cloudcoverpercentage': 0.2425,
#    'sensoroperationalmode': 'INS-NOBS',
#    'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>41.5268622914542,-0.603302 41.49194363396281,0.710574648674325 40.50488583658978,0.65555501440102 40.53861750192735,-0.6388855 41.5268622914542,-0.603302</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#    'footprint': 'MULTIPOLYGON (((0.65555501440102 40.50488583658978, 0.710574648674325 41.49194363396281, -1.2757692614189051e-17 41.51082844541308, -0.603302 41.5268622914542, -0.6388855 40.53861750192735, 1.9339596288131015e-17 40.52196886366605, 0.65555501440102 40.50488583658978)))',
#    'tileid': '30TYL',
#    'hv_order_tileid': 'TL30Y',
#    'format': 'SAFE',
#    'processingbaseline': '02.07',
#    'platformname': 'Sentinel-2',
#    'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T30TYL_20190501T130728.SAFE',
#    'instrumentname': 'Multi-Spectral Instrument',
#    'instrumentshortname': 'MSI',
#    'size': '852.67 MB',
#    's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#    'producttype': 'S2MSI1C',
#    'platformidentifier': '2017-013A',
#    'orbitdirection': 'DESCENDING',
#    'platformserialidentifier': 'Sentinel-2B',
#    'processinglevel': 'Level-1C',
#    'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T30TYL_20190501T130728',
#    'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T30TYL_N02.07',
#    'uuid': '7716ec35-1644-4228-9c53-5dd9769ca7e1',
#    'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T30TYL_N02.07',
#    'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'}),
#  ('47fc1c3b-5d33-4c93-9b85-5cb85048a225',
#   {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCE_20190501T130728',
#    'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('47fc1c3b-5d33-4c93-9b85-5cb85048a225')/$value",
#    'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('47fc1c3b-5d33-4c93-9b85-5cb85048a225')/",
#    'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('47fc1c3b-5d33-4c93-9b85-5cb85048a225')/Products('Quicklook')/$value",
#    'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 529.59 MB',
#    'ondemand': 'false',
#    'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'ingestiondate': datetime.datetime(2019, 5, 1, 18, 25, 38, 108000),
#    'orbitnumber': 11231,
#    'relativeorbitnumber': 51,
#    'cloudcoverpercentage': 0.9141,
#    'sensoroperationalmode': 'INS-NOBS',
#    'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>40.643047737221266,1.73935014766585 40.617025151275946,1.729937943974527 40.47079155758107,1.67721340422739 40.32446770303216,1.624540912067755 40.178082437376425,1.571999987811006 40.031631736700575,1.519690524897823 39.885181580616525,1.467620933702627 39.7387242344685,1.415691129887569 39.64862346318864,1.383837310903674 39.638218234831534,0.669348697399363 40.62663972727231,0.635319212972606 40.643047737221266,1.73935014766585</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#    'footprint': 'MULTIPOLYGON (((0.669348697399363 39.638218234831534, 1.383837310903674 39.64862346318864, 1.415691129887569 39.7387242344685, 1.467620933702627 39.885181580616525, 1.519690524897823 40.031631736700575, 1.571999987811006 40.178082437376425, 1.624540912067755 40.32446770303216, 1.67721340422739 40.47079155758107, 1.729937943974527 40.617025151275946, 1.73935014766585 40.643047737221266, 0.635319212972606 40.62663972727231, 0.669348697399363 39.638218234831534)))',
#    'tileid': '31TCE',
#    'hv_order_tileid': 'TE31C',
#    'format': 'SAFE',
#    'processingbaseline': '02.07',
#    'platformname': 'Sentinel-2',
#    'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCE_20190501T130728.SAFE',
#    'instrumentname': 'Multi-Spectral Instrument',
#    'instrumentshortname': 'MSI',
#    'size': '529.59 MB',
#    's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#    'producttype': 'S2MSI1C',
#    'platformidentifier': '2017-013A',
#    'orbitdirection': 'DESCENDING',
#    'platformserialidentifier': 'Sentinel-2B',
#    'processinglevel': 'Level-1C',
#    'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCE_20190501T130728',
#    'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TCE_N02.07',
#    'uuid': '47fc1c3b-5d33-4c93-9b85-5cb85048a225',
#    'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TCE_N02.07',
#    'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'}),
#  ('62952613-1ac4-4ade-93a3-8657fb3b84b5',
#   {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBF_20190501T130728',
#    'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('62952613-1ac4-4ade-93a3-8657fb3b84b5')/$value",
#    'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('62952613-1ac4-4ade-93a3-8657fb3b84b5')/",
#    'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('62952613-1ac4-4ade-93a3-8657fb3b84b5')/Products('Quicklook')/$value",
#    'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 853.27 MB',
#    'ondemand': 'false',
#    'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'ingestiondate': datetime.datetime(2019, 5, 1, 18, 24, 49, 775000),
#    'orbitnumber': 11231,
#    'relativeorbitnumber': 51,
#    'cloudcoverpercentage': 0.2712,
#    'sensoroperationalmode': 'INS-NOBS',
#    'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>41.49564643575739,-0.5941162 41.52923550071836,0.719948115495856 40.54090999482793,0.753813881598681 40.50846282585221,-0.5408325 41.49564643575739,-0.5941162</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#    'footprint': 'MULTIPOLYGON (((-0.5408325 40.50846282585221, 1.3101912763842559e-17 40.52201747966694, 0.753813881598681 40.54090999482793, 0.719948115495856 41.52923550071836, -5.6985729713309160e-18 41.51083276065857, -0.5941162 41.49564643575739, -0.5408325 40.50846282585221)))',
#    'tileid': '31TBF',
#    'hv_order_tileid': 'TF31B',
#    'format': 'SAFE',
#    'processingbaseline': '02.07',
#    'platformname': 'Sentinel-2',
#    'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBF_20190501T130728.SAFE',
#    'instrumentname': 'Multi-Spectral Instrument',
#    'instrumentshortname': 'MSI',
#    'size': '853.27 MB',
#    's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#    'producttype': 'S2MSI1C',
#    'platformidentifier': '2017-013A',
#    'orbitdirection': 'DESCENDING',
#    'platformserialidentifier': 'Sentinel-2B',
#    'processinglevel': 'Level-1C',
#    'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TBF_20190501T130728',
#    'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TBF_N02.07',
#    'uuid': '62952613-1ac4-4ade-93a3-8657fb3b84b5',
#    'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TBF_N02.07',
#    'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'}),
#  ('bb9027de-6f91-43e4-8cd9-bf35cfc448a9',
#   {'title': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCF_20190501T130728',
#    'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('bb9027de-6f91-43e4-8cd9-bf35cfc448a9')/$value",
#    'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('bb9027de-6f91-43e4-8cd9-bf35cfc448a9')/",
#    'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('bb9027de-6f91-43e4-8cd9-bf35cfc448a9')/Products('Quicklook')/$value",
#    'summary': 'Date: 2019-05-01T10:50:39.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 760.49 MB',
#    'ondemand': 'false',
#    'datatakesensingstart': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'beginposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'endposition': datetime.datetime(2019, 5, 1, 10, 50, 39, 24000),
#    'ingestiondate': datetime.datetime(2019, 5, 1, 18, 21, 9, 81000),
#    'orbitnumber': 11231,
#    'relativeorbitnumber': 51,
#    'cloudcoverpercentage': 2.3334,
#    'sensoroperationalmode': 'INS-NOBS',
#    'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>41.15311144037381,1.924907491200061 41.05550012725967,1.889168309245836 40.90937535066946,1.835866226759284 40.76322949618436,1.782819124873532 40.617025151275946,1.729937943974527 40.5544664448336,1.707382394862937 40.538607851727775,0.638419022640916 41.52685230149302,0.6028173807795 41.546758769895376,1.918508192616414 41.15311144037381,1.924907491200061</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#    'footprint': 'MULTIPOLYGON (((0.638419022640916 40.538607851727775, 1.707382394862937 40.5544664448336, 1.729937943974527 40.617025151275946, 1.782819124873532 40.76322949618436, 1.835866226759284 40.90937535066946, 1.889168309245836 41.05550012725967, 1.924907491200061 41.15311144037381, 1.918508192616414 41.546758769895376, 0.6028173807795 41.52685230149302, 0.638419022640916 40.538607851727775)))',
#    'tileid': '31TCF',
#    'hv_order_tileid': 'TF31C',
#    'format': 'SAFE',
#    'processingbaseline': '02.07',
#    'platformname': 'Sentinel-2',
#    'filename': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCF_20190501T130728.SAFE',
#    'instrumentname': 'Multi-Spectral Instrument',
#    'instrumentshortname': 'MSI',
#    'size': '760.49 MB',
#    's2datatakeid': 'GS2B_20190501T105039_011231_N02.07',
#    'producttype': 'S2MSI1C',
#    'platformidentifier': '2017-013A',
#    'orbitdirection': 'DESCENDING',
#    'platformserialidentifier': 'Sentinel-2B',
#    'processinglevel': 'Level-1C',
#    'identifier': 'S2B_MSIL1C_20190501T105039_N0207_R051_T31TCF_20190501T130728',
#    'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TCF_N02.07',
#    'uuid': 'bb9027de-6f91-43e4-8cd9-bf35cfc448a9',
#    'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_MPS__20190501T130728_A011231_T31TCF_N02.07',
#    'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_MPS__20190501T130728_S20190501T105819_N02.07'})]

# %%
extra_env = {'SENTINEL_USERNAME': SENTINEL_USERNAME,
             'SENTINEL_PASSWORD': SENTINEL_PASSWORD}

fexec = lithops.FunctionExecutor(backend=BATCH_BACKEND, storage=STORAGE_BACKEND, runtime=BATCH_RUNTIME)
# Out:
# 2023-10-08 02:22:22,233 [INFO] config.py:141 -- Lithops v2.9.1.dev0 - Python3.8
# 2023-10-08 02:22:22,240 [WARNING] config.py:104 -- Timeout set to 7200 - 10000 exceeds the maximum amount
# 2023-10-08 02:22:22,246 [INFO] aws_s3.py:68 -- S3 client created - Region: us-west-2
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
# 2023-10-08 02:22:24,334 [INFO] aws_batch.py:75 -- AWS Batch client created - Region: us-west-2

# %%
# Needs to be sequential
dw_data_fs = []
for product in iterdata:
    fut = fexec.call_async(download_dataset, product, extra_env=extra_env)
    fexec.wait(fs=fut)
    dw_data_fs.append(fut)
# Out:
# 2023-10-07 00:52:54,702 [INFO] invokers.py:108 -- ExecutorID e5eb52-0 | JobID A000 - Selected Runtime: cloudbutton-geospatial-sentinel:01 - 2048MB
# &&&&&&&&&&&&&&&&&&& self.parameters.values() odict_values([<Parameter "self">, <Parameter "conn=None">])
# &&&&&&&&&&&&&&&&&&& args (<IPython.core.history.HistoryManager object at 0x7f16144482b0>, <sqlite3.Connection object at 0x7f1614621990>)
# 2023-10-07 00:52:55,529 [INFO] invokers.py:116 -- Runtime cloudbutton-geospatial-sentinel:01 with 2048MB is not yet deployed
# 2023-10-07 00:52:55,531 [INFO] aws_batch.py:414 -- Deploying runtime: cloudbutton-geospatial-sentinel:01 - Memory: 2048 Timeout: 7200
# 2023-10-07 00:53:04,912 [INFO] aws_batch.py:319 -- Extracting metadata from: cloudbutton-geospatial-sentinel:01
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 dw_data_fs = []
#       3 for product in iterdata:
# ----> 4     fut = fexec.call_async(download_dataset, product, extra_env=extra_env)
#       5     fexec.wait(fs=fut)
#       6     dw_data_fs.append(fut)
#
# File ~/miniconda3/envs/python3.8/lib/python3.8/site-packages/lithops/executors.py:190, in FunctionExecutor.call_async(self, func, data, extra_env, runtime_memory, timeout, include_modules, exclude_modules)
#     187 job_id = self._create_job_id('A')
#     188 self.last_call = 'call_async'
# --> 190 runtime_meta = self.invoker.select_runtime(job_id, runtime_memory)
#     192 job = create_map_job(config=self.config,
#     193                      internal_storage=self.internal_storage,
#     194                      executor_id=self.executor_id,
#    (...)
#     202                      exclude_modules=exclude_modules,
#     203                      execution_timeout=timeout)
#     205 futures = self.invoker.run_job(job)
#
# File ~/miniconda3/envs/python3.8/lib/python3.8/site-packages/lithops/invokers.py:117, in Invoker.select_runtime(self, job_id, runtime_memory)
#     115 msg = msg + f' with {runtime_memory}MB' if runtime_memory else msg
#     116 logger.info(msg + ' is not yet deployed')
# --> 117 runtime_meta = self.compute_handler.deploy_runtime(self.runtime_name, runtime_memory, runtime_timeout)
#     118 runtime_meta['runtime_timeout'] = runtime_timeout
#     119 self.internal_storage.put_runtime_meta(runtime_key, runtime_meta)
#
# File ~/miniconda3/envs/python3.8/lib/python3.8/site-packages/lithops/serverless/serverless.py:73, in ServerlessHandler.deploy_runtime(self, runtime_name, memory, timeout)
#      68 def deploy_runtime(self, runtime_name, memory, timeout):
#      69     """
#      70     Wrapper method to deploy a runtime in the compute backend.
#      71     return: the name of the runtime
#      72     """
# ---> 73     return self.backend.deploy_runtime(runtime_name, memory, timeout=timeout)
#
# File ~/miniconda3/envs/python3.8/lib/python3.8/site-packages/lithops/serverless/backends/aws_batch/aws_batch.py:419, in AWSBatchBackend.deploy_runtime(self, runtime_name, memory, timeout)
#     416 self._create_queue()
#     417 self._create_job_def(runtime_name, memory)
# --> 419 runtime_meta = self._generate_runtime_meta(runtime_name, memory)
#     420 return runtime_meta
#
# File ~/miniconda3/envs/python3.8/lib/python3.8/site-packages/lithops/serverless/backends/aws_batch/aws_batch.py:359, in AWSBatchBackend._generate_runtime_meta(self, runtime_name, runtime_memory)
#     357         time.sleep(20)
#     358         retry += 1
# --> 359 raise Exception('Could not get metadata')
#
# Exception: Could not get metadata

# %% [markdown]
# ## Athmospheric correction using Serverful Lithops

# %% [markdown]
# Here we will download tile images from Sentinel2 using the previously selected configuration and apply athmospheric correction.
#
# This process is not parallelizable and lasts for over 25 minutes, so it is not suited for serverless functions. We will use Lithops Standalone instead, which uses serverful instances that haven't time limits.

# %%
def jp2_to_cog(band_src_path):
    """
    Transform a sentinel2 band (.jp2) to GeoTiff (.tif)
    """
    config = dict(NUM_THREADS=100, GDAL_TIFF_OVR_BLOCKSIZE=128)

    output_profile = {
        "driver": "GTiff",
        "interleave": "pixel",
        "tiled": True,
        "blockxsize": 256,
        "blockysize": 256,
        "compress": "DEFLATE",
    }

    cog_path = f"{band_src_path[band_src_path.rfind('/')+1:band_src_path.rfind('.')]}.tif"
    cogeo.cog_translate(
        band_src_path,
        cog_path,
        output_profile,
        nodata=0,
        in_memory=False,
        config=config,
        quiet=True,
    )

    return cog_path

# %%
def perform_atmospheric_correction(product_geojson, storage):
    product = product_geojson['properties']
    tile = product['filename'][39:44]
    date = product['filename'][11:19]

    tmpdir = tempfile.gettempdir()
    
    product_local_file = os.path.join(tmpdir, product['identifier']+'.zip')
    product_storage_key = os.path.join('sentinel', product['identifier']+'.zip')
    
    if not os.path.isfile(product_local_file):
        print(f'Copying {product_storage_key} to local disk')
        obj_stream = storage.get_object(bucket=STORAGE_BUCKET, key=product_storage_key, stream=True)    
        with open(product_local_file, 'wb') as shapf:
            shutil.copyfileobj(obj_stream, shapf)
        print(f'Finished copying {product_storage_key} to local disk')
 
    # Extract and remove zip file
    print('Extracting zip file')
    zip_ref = zipfile.ZipFile(product_local_file)
    zip_ref.extractall(tmpdir)
    zip_ref.close()

    # Atmospheric correction
    print('Starting atmospheric correction')
    sentinel_product_dir = os.path.join(tmpdir, product['filename'])
    corrected_images = glob.glob(f"*2A_{date}*_T{tile}_*.SAFE/GRANULE/*/IMG_DATA/R10m/*B0[48]*.jp2")
    atmospheric_corrected = corrected_images[0] if len(corrected_images) > 0 else None

    if not atmospheric_corrected:
        print(f'Doing the atmospheric correction for {sentinel_product_dir}')
        retry = 0
        while True:
            try:
                cmd = ['L2A_Process --resolution 10 {}'.format(sentinel_product_dir)]
                val = subprocess.check_output(cmd, stderr=subprocess.STDOUT, shell=True, universal_newlines=True)
                corrected_images = glob.glob(f"*2A_{date}*_T{tile}_*.SAFE/GRANULE/*/IMG_DATA/R10m/*B0[48]*.jp2")
                print(f'Atmospheric correction finished {val}')
                break
            except subprocess.CalledProcessError as e:
                if retry<3:
                    retry += 1
                    time.sleep(2)
                else:   
                    print(e.returncode)
                    print(e.output)
                    raise(e)


    # Translate bands in .jp2 to GeoTiff format
    band_files = []
    band4 = glob.glob(os.path.join(tmpdir, '*L2A_{}*_T{}*.SAFE/GRANULE/*/IMG_DATA/R10m/*B04*'.format(date, tile))).pop()
    band8 = glob.glob(os.path.join(tmpdir, '*L2A_{}*_T{}*.SAFE/GRANULE/*/IMG_DATA/R10m/*B08*'.format(date, tile))).pop()

    if band4 is not None and band8 is not None:
        band4_tiff_file = f"{band4[band4.rfind('/')+1:band4.rfind('.')]}.tif"
        band8_tiff_file = f"{band8[band8.rfind('/') + 1:band8.rfind('.')]}.tif"
        jp2_to_cog(band4)
        jp2_to_cog(band8)
        band_files.append(band4_tiff_file)
        band_files.append(band8_tiff_file)
    
    print(band_files)

    # Merge both bands into a single geotiff
    combined_geotiff_key = band_files[0][0:22] + '_COMBINED.tif'
    with rasterio.open(band_files[0]) as src:
        profile = src.profile
        profile.update(count=len(band_files))

    with rasterio.open(combined_geotiff_key, 'w', **profile) as dst:
        for i, band_file in enumerate(band_files):
            with rasterio.open(band_file) as src:
                dst.write(src.read(1), i + 1)

    # Upload generated files to Cloud Storage
    with open(combined_geotiff_key, 'rb') as combined_geotiff_f:
        storage.put_object(Bucket=STORAGE_BUCKET, Key=combined_geotiff_key, Body=combined_geotiff_f)
    product_meta_key = combined_geotiff_key + '.meta.json'
    storage.put_object(Bucket=STORAGE_BUCKET, Key=product_meta_key, Body=json.dumps(product))

    return combined_geotiff_key

# %%
# print(geojson_products["features"])

# %%
# fexec = lithops.FunctionExecutor(backend='aws_batch', storage='aws_s3', runtime=BATCH_RUNTIME)

fexec.map(perform_atmospheric_correction, geojson_products["features"])

combined_keys = fexec.get_result()

# %%
combined_keys

# %% [markdown]
# ## NDVI Computation using Serverless Lithops

# %% [markdown]
# Now we will calculate NDVI index of tiles tha thave been downloaded and pre-processed before.
#
# This process can be executed in parallel (for every tile) and in serverless functions.

# %%
# debug
# combined_keys = ['T30SXG_20201229T110451_COMBINED.tif']

# %%
def ndvi(combined_key, storage):
    tmpdir = tempfile.gettempdir()
    dat = storage.get_object(bucket=STORAGE_BUCKET, key=combined_key, stream=True)
    out = os.path.join(tmpdir, 'out.tif')

    with rasterio.open(dat) as src:
        profile = src.profile
        profile.update(dtype='float32')
        profile.update(count=1)
        with rasterio.open(out, 'w', **profile) as dst:
            for _, window in src.block_windows(1):
                red = src.read(1, window=window).astype('float32')
                nir = src.read(2, window=window).astype('float32')
                ndvi = (np.where((nir + red) == 0., 0,
                                 (nir - red) / (nir + red))).astype('float32')
                dst.write(ndvi, 1, window=window)

    prefix = combined_key.rsplit('_', 1)[0]
    output_key = prefix + '_NDVI.tif'
    with open(out, 'rb') as output_f:
        storage.put_object(bucket=STORAGE_BUCKET, key=output_key, body=output_f)

    return output_key

# %%
fexec = lithops.FunctionExecutor(backend=COMPUTE_BACKEND, storage=STORAGE_BACKEND,
                                 runtime=RUNTIME, runtime_memory=2048, log_level='DEBUG')
fexec.map(ndvi, combined_keys, timeout=60)
ndvi_keys = fexec.get_result()

# %%
ndvi_keys

# %%
# debug
# ndvi_keys = ['T30SXG_20201229T110451_NDVI.tif']

# %%
tile_select = notebook_utils.pick_tile(ndvi_keys)

# %%
obj = cloud_storage.get_object(bucket=STORAGE_BUCKET, key=tile_select.value, stream=True)

fig, axs = plt.subplots(figsize=(20,15))

with rasterio.open(obj) as src:
#     ij, window = random.choice(list(src.block_windows()))
#     arr = src.read(1, window=window)
    arr = src.read(1)
    plt.imshow(arr)
